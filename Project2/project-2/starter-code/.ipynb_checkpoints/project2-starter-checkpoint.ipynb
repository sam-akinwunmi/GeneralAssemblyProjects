# %% [markdown]
# # Project 2
#
# In this project, you will implement the exploratory analysis plan developed in Project 1. This will lay the groundwork for our our first modeling exercise in Project 3.

# %% [markdown]
# ### Step 1: Load the python libraries you will need for this project

# %%
#imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Step 2: Read in your data set

# %%
#Read in data from source 
df_raw = pd.read_csv("../assets/admissions.csv")
print df_raw.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Questions
# #### Question 1. How many observations are in our dataset?

# %%
df_raw.count()
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %% [markdown]
# Answer: There are 400 observations in the data set, but there are some observations with missing GRE, GPA & Prestige values

# %% [markdown]
# #### Question 2. Create a summary table

# %%
df_raw.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000

# %% [markdown]
# #### Question 3. Why would GRE have a larger STD than GPA?

# %% [markdown]
# Answer: Because GRE has a  much larger range of values than GPA. GRE goes from 220 to 800, whilst GPA ranges from 2.3 to 4

# %% [markdown]
# #### Question 4. Drop data points with missing data

# %%
df_new = df_raw.dropna()
df_new.count()
# Out:
# admit       397
# gre         397
# gpa         397
# prestige    397
# dtype: int64

# %% [markdown]
# #### Question 5. Confirm that you dropped the correct data. How can you tell?

# %%
df_new.isnull().sum()
# Out:
# admit       0
# gre         0
# gpa         0
# prestige    0
# dtype: int64

# %% [markdown]
# #### Question 6. Create box plots for GRE and GPA

# %%
df_new['gre'].plot(kind="box")

# %%
df_new['gpa'].plot(kind="box")

# %% [markdown]
# #### Question 7. What do this plots show?

# %% [markdown]
# Answer: Box plots are a nice way to get a visual of the max, min, median, and the quartile and interquartile range

# %% [markdown]
# #### Question 8. Describe each distribution

# %%
# plot the distribution of each variable
plt.subplot(211)
df_new['gre'].plot(kind="hist")
plt.subplot(212)
df_new['gpa'].plot(kind="hist")

# %% [markdown]
# #### Question 9.  If our model had an assumption of a normal distribution would we meet that requirement?

# %% [markdown]
# Answer: We could possibly still model the data using these distributions, but it would be better to correct them as they don't have perfect bell shaped distributions

# %% [markdown]
# #### Question 10.  Does this distribution need correction? If so, why? How?

# %% [markdown]
# We should correct the data to be normally distributed because statistical relationships become clear and tractable if one assumes the normal. There are a large number of different transformations that we can use the transform the data to a normal distribution, such as logarithmic transformation, square root transformation and so on.

# %% [markdown]
# #### Question 11. Which of our variables are potentially colinear?

# %%
# create a correlation matrix for the data
df_new.corr()
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.181202  0.174116 -0.243563
# gre       0.181202  1.000000  0.382408 -0.124533
# gpa       0.174116  0.382408  1.000000 -0.060976
# prestige -0.243563 -0.124533 -0.060976  1.000000

# %% [markdown]
# #### Question 12. What did you find?

# %% [markdown]
# Answer: None of the variables are overly correlated to each other. The variables with the highest correlation are GRE and GPA

# %% [markdown]
# #### Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of  undergraduate schools.

# %% [markdown]
# Answer: Because the dataset has a binary response (ie. 1 or 0) I will be using a logistic regression model to model the log odds of a candidate being admitted based on their GRE, GPA and Prestige. In order to model prestige, I will "dummify" the prestige variable, using the prestige = 1 as the base.

# %% [markdown]
# #### Question 14. What is your hypothesis?

# %% [markdown]
# Answer: My hypothesis is that there will be a statistically significant positive relationship between GRE, GPA and admission into graduate school. Finally I think that there will also be a statistically significant negative relationship between the undergraduate prestige and admission. People who go to a worse undergraduate school will have less chance of being admitted.

# %% [markdown]
# ## Bonus/Advanced

# %% [markdown]
# #### 1. Bonus: Explore alternatives to dropping obervations with missing data

# %% [markdown]
# Instead of dropping missed observations, we can use the various different imputation methods such as mean imputation, median imputation, and most frequent value imputation

# %% [markdown]
# #### 2. Bonus: Log transform the skewed data

# %%
df_log = pd.DataFrame()

df_log['gre'] = np.log(df_new['gre'])
df_log['gpa'] = np.log(df_new['gpa'])

df_log.head()
# Out:
#         gre       gpa
# 0  5.940171  1.283708
# 1  6.492240  1.300192
# 2  6.684612  1.386294
# 3  6.461468  1.160021
# 4  6.253829  1.075002

# %% [markdown]
# #### 3. Advanced: Impute missing data

# %%
# mean imputation
df_raw.fillna(df_raw.mean())
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# 5        1  760.0  3.00       2.0
# 6        1  560.0  2.98       1.0
# 7        0  400.0  3.08       2.0
# 8        1  540.0  3.39       3.0
# 9        0  700.0  3.92       2.0
# 10       0  800.0  4.00       4.0
# 11       0  440.0  3.22       1.0
# 12       1  760.0  4.00       1.0
# 13       0  700.0  3.08       2.0
# 14       1  700.0  4.00       1.0
# 15       0  480.0  3.44       3.0
# 16       0  780.0  3.87       4.0
# 17       0  360.0  2.56       3.0
# 18       0  800.0  3.75       2.0
# 19       1  540.0  3.81       1.0
# 20       0  500.0  3.17       3.0
# 21       1  660.0  3.63       2.0
# 22       0  600.0  2.82       4.0
# 23       0  680.0  3.19       4.0
# 24       1  760.0  3.35       2.0
# 25       1  800.0  3.66       1.0
# ...

# %%
# median imputation
df_raw.fillna(df_raw.median())
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# 5        1  760.0  3.00       2.0
# 6        1  560.0  2.98       1.0
# 7        0  400.0  3.08       2.0
# 8        1  540.0  3.39       3.0
# 9        0  700.0  3.92       2.0
# 10       0  800.0  4.00       4.0
# 11       0  440.0  3.22       1.0
# 12       1  760.0  4.00       1.0
# 13       0  700.0  3.08       2.0
# 14       1  700.0  4.00       1.0
# 15       0  480.0  3.44       3.0
# 16       0  780.0  3.87       4.0
# 17       0  360.0  2.56       3.0
# 18       0  800.0  3.75       2.0
# 19       1  540.0  3.81       1.0
# 20       0  500.0  3.17       3.0
# 21       1  660.0  3.63       2.0
# 22       0  600.0  2.82       4.0
# 23       0  680.0  3.19       4.0
# 24       1  760.0  3.35       2.0
# 25       1  800.0  3.66       1.0
# ...
